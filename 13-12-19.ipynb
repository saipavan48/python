# %%
![TEXT]()

# %% [markdown]
# ![TEXT](https://cdn.wallpapersafari.com/86/47/jResQu.jpg)

# %%
# variable creation
a=10
b=20
a+b
# Out:
# 30

# %%
# basic hello
print("hello world")
# Out:
# hello world

# %% [markdown]
# # rules for variable
# - name should begin with charecter
# - no specific character allowed except _

# %%
name="ajay"
age=67
print("my name is:",name,"age is:",age)
# Out:
# my name is: ajay age is: 67

# %%
name = input ("enter name")
age=int(input("enter age"))
print("my name is: ",name,"age is: ",age)
# Out:
# enter nameasd
# enter age12
# my name is:  asd age is:  12

# %%
a = int(input ("value of a"))
b = int(input ("value of b"))
print ("a+b=",a+b,"a-b=",a-b,"a*b=",a*b,"a/b=",a/b)
# Out:
# value of a20
# value of b5
# a+b= 25 a-b= 15 a*b= 100 a/b= 4.0

# %% [markdown]
# # fundamental datatypes:
# - int
# - float
# - complex
# - boolean
# - string

# %%
x=10
y=12.45
z=5+6j
print(type(x),type(y),type(z))
# Out:
# <class 'int'> <class 'float'> <class 'complex'>

# %%
c =complex(2,3)
print(c)
# Out:
# (2+3j)

# %%
C1=3+5j
C2=6+7j
print(C1+C2,C1-C2,C1*C2)
# Out:
# (9+12j) (-3-2j) (-17+51j)

# %%
x=6
y=9
x<y
# Out:
# True

# %%
s1="asdd"
s2="asd"
print (type(s1),type(s2))
# Out:
# <class 'str'> <class 'str'>

# %%
i=100
print(type(i))
s1=str(i)
print(type(s1))
f1=float(i)
print(type(f1))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
a=12345
print(len(str(a)))
# Out:
# 5

# %%
n1=100
a=b=c=20
a1,b1,c1=123,234,345
print(n1)
print(a,b,c)
print(b1,a1,c1)
# Out:
# 100
# 20 20 20
# 234 123 345

# %%
x=1+2**3/4+5
print(x
      
      )
# Out:
# 8.0

# %%
x=1+2**3/4*5
print(x)
# Out:
# 11.0

# %% [markdown]
# # operators
# ## arithmatic operators
# - +
# - -
# - *
# - /
# - %
# - **
# - //

# %% [markdown]
# # relational operators
# - "=="
# - "!="
# - "<"
# - ">"
# - "<="
# - ">="

# %%
# check given number is even or odd
n=int(input("enter a number") )
if n%2 ==0:
  print("even")
else:
    print ("odd")
# Out:
# enter a number12
# even

# %%
n=int(input("enter a number") )
if n%5 ==0 and n%3 ==0:
  print("yes")
else:
    print ("no")
# Out:
# enter a number13
# no

# %%
n=int(input("enter a number") )
if n ==0 :
  print("zer0")
elif n<0:
  
    print ("negitie")
else: 
    print("positive")
# Out:
# enter a number5
# positive
